# %%
import pandas as pd
pd.set_option('display.max_columns',10)
print("Original data:\n")
df=pd.read_csv("mark list excel . spreadsheet - Sheet1.csv")
print(df)
# Out:
# Original data:
#
#    Roll      Name  English  Tamil  Maths  Total
# 0   101    Rosman     50.0     67     50    284
# 1   102     Kavya     56.0     89     56    346
# 2   103   Rebacca     80.0     80     80    400
# 3   104     Ramya     89.0     87     89    441
# 4   105     Rohan      NaN     98     90    466
# 5   106  Srimathi     67.0     76     67    353
# 6   107    Vishnu     56.0     67     56    302

# %%
F=df['Name'].str.strip()
F.to_csv("mark list excel . spreadsheet - Sheet1.csv")
print("\n Replace value:")
k=df.ffill()
print(k)
print("\nupdated list\n")
k.to_csv("mark list excel . spreadsheet - Sheet1.csv")
# Out:
#  Replace value:
#    Roll      Name  English  Tamil  Maths  Total
# 0   101    Rosman     50.0     67     50    284
# 1   102     Kavya     56.0     89     56    346
# 2   103   Rebacca     80.0     80     80    400
# 3   104     Ramya     89.0     87     89    441
# 4   105     Rohan     89.0     98     90    466
# 5   106  Srimathi     67.0     76     67    353
# 6   107    Vishnu     56.0     67     56    302
#
# updated list

# %%
print("\n drop one particular column and its values:\n")
# k.drop(['Social'],axis=1,inplace=True) # Commented out as 'Social' column does not exist
print("Current columns in DataFrame k:", k.columns.tolist())
print(k)
print("\n Updated list\n")
k.to_csv("mark list excel . spreadsheet - Sheet1.csv")
# Out:
#  drop one particular column and its values:
#
# Current columns in DataFrame k: ['Roll', 'Name', 'English', 'Tamil', 'Maths', 'Total']
#    Roll      Name  English  Tamil  Maths  Total
# 0   101    Rosman     50.0     67     50    284
# 1   102     Kavya     56.0     89     56    346
# 2   103   Rebacca     80.0     80     80    400
# 3   104     Ramya     89.0     87     89    441
# 4   105     Rohan     89.0     98     90    466
# 5   106  Srimathi     67.0     76     67    353
# 6   107    Vishnu     56.0     67     56    302
#
#  Updated list

# %%
print("\n drop NaN rows:\n")
df=pd.read_csv("mark list excel . spreadsheet - Sheet1.csv")
print(df)
x=df.dropna()
print(x)
print("\n upated data list:\n")
x.to_csv("mark list excel . spreadsheet - Sheet1.csv")
# Out:
#  drop NaN rows:
#
#    Unnamed: 0.1  Unnamed: 0  Roll      Name  English  Tamil  Maths  Total
# 0             0           0   101    Rosman     50.0     67     50    284
# 1             1           1   102     Kavya     56.0     89     56    346
# 2             2           2   103   Rebacca     80.0     80     80    400
# 3             3           3   104     Ramya     89.0     87     89    441
# 4             4           4   105     Rohan     89.0     98     90    466
# 5             5           5   106  Srimathi     67.0     76     67    353
# 6             6           6   107    Vishnu     56.0     67     56    302
#    Unnamed: 0.1  Unnamed: 0  Roll      Name  English  Tamil  Maths  Total
# 0             0           0   101    Rosman     50.0     67     50    284
# 1             1           1   102     Kavya     56.0     89     56    346
# 2             2           2   103   Rebacca     80.0     80     80    400
# ...

# %%
df=pd.read_csv("mark list excel . spreadsheet - Sheet1.csv")
print(df)
print("\n Extract using is in()functin:\n")
new=df['English'].isin([88])
print(df[new])
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  Roll      Name  English  Tamil  \
# 0             0             0           0   101    Rosman     50.0     67
# 1             1             1           1   102     Kavya     56.0     89
# 2             2             2           2   103   Rebacca     80.0     80
# 3             3             3           3   104     Ramya     89.0     87
# 4             4             4           4   105     Rohan     89.0     98
# 5             5             5           5   106  Srimathi     67.0     76
# 6             6             6           6   107    Vishnu     56.0     67
#
#    Maths  Total
# 0     50    284
# 1     56    346
# 2     80    400
# 3     89    441
# 4     90    466
# 5     67    353
# 6     56    302
#
#  Extract using is in()functin:
#
# Empty DataFrame
# Columns: [Unnamed: 0.2, Unnamed: 0.1, Unnamed: 0, Roll, Name, English, Tamil, Maths, Total]
# Index: []
