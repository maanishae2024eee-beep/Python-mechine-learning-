# %%
import pandas as pd
import numpy as np

# Creating a dummy DataFrame of 12 numbers randomly ranging from 150-180 for height
df = pd.DataFrame({'Height': [150.4, 157.6, 170, 176, 164.2, 155,
                             159.2, 175, 162.4, 176, 153, 170]})

# Printing DataFrame before sorting continuous to categories
print("Before:")
print(df)

# Categorizing Height into 3 Categories
# Short: (150,157]
# Average: (157,169]
# Tall: (169,180]

df['Label'] = pd.cut(df['Height'],
                     bins=[150, 157, 169, 180],
                     labels=['Short', 'Average', 'Tall'])

# Printing DataFrame after categorization
print("After:")
print(df)

# Check number of values in each bin
print("Categories:")
print(df['Label'].value_counts())
# Out:
# Before:
#     Height
# 0    150.4
# 1    157.6
# 2    170.0
# 3    176.0
# 4    164.2
# 5    155.0
# 6    159.2
# 7    175.0
# 8    162.4
# 9    176.0
# 10   153.0
# 11   170.0
# After:
#     Height    Label
# 0    150.4    Short
# 1    157.6  Average
# 2    170.0     Tall
# 3    176.0     Tall
# 4    164.2  Average
# 5    155.0    Short
# 6    159.2  Average
# 7    175.0     Tall
# 8    162.4  Average
# 9    176.0     Tall
# 10   153.0    Short
# 11   170.0     Tall
# Categories:
# Label
# Tall       5
# Average    4
# Short      3
# Name: count, dtype: int64
