# %%
import numpy as np
arr=np.array([[-1,2,0,4],[4,-0.5,6,0],[2.6,0,7,8],[3,-7,4,2.0]])
print("Original array:\n",arr)
# Out:
# Original array:
#  [[-1.   2.   0.   4. ]
#  [ 4.  -0.5  6.   0. ]
#  [ 2.6  0.   7.   8. ]
#  [ 3.  -7.   4.   2. ]]

# %%
print("\nEvery other rows:\n",arr[0:3:2])
# Out:
# Every other rows:
#  [[-1.   2.   0.   4. ]
#  [ 2.6  0.   7.   8. ]]

# %%
arr=np.array([1,2,3,4,5,6,7])
print("\nOriginal array:",arr)
print("\nReturns every other elements in the array:arr[::2]:",arr[::2])
# Out:
# Original array: [1 2 3 4 5 6 7]
#
# Returns every other elements in the array:arr[::2]: [1 3 5 7]

# %%
arr=np.array([[-1,2,0,4],[4,0.5,6,0],[2.6,0,7,8],[3,-7,4,2.0]])
temp=arr[:2,:3]
print("\nArray with first 2 rows & 3 columns:\n",temp)
# Out:
# Array with first 2 rows & 3 columns:
#  [[-1.   2.   0. ]
#  [ 4.   0.5  6. ]]

# %%
t=arr[[0,1,2,3],[3,2,1,0]]
print("\nElements at indices(0,3),(1,2),(3,0):[4.6.0.3.]")
# Out:
# Elements at indices(0,3),(1,2),(3,0):[4.6.0.3.]

# %%
cond=arr>2
temp=arr[cond]
print("\nElements greater than 2:\n",temp)
# Out:
# Elements greater than 2:
#  [4.  4.  6.  2.6 7.  8.  3.  4. ]
